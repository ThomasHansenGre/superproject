# %%
from main import main

# %%
main()
# Out:
# Hello from superproject!

# %%
import sys
sys.path.append('..')

# %%
from superproject.func import *
my_super_function()
# Out:
# Super function iteration 0
# Super function iteration 1
# Super function iteration 2
# Super function iteration 3
# Super function iteration 4
